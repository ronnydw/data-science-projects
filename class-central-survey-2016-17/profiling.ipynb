# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import pandas_profiling
import numpy as np

# %% [markdown]
# # Load dataset

# %%
df = pd.read_csv('raw/2016-17-ClassCentral-Survey-data-noUserText.csv', decimal=',', encoding = "ISO-8859-1")

# %%
df["Timestamp"] = pd.to_datetime(df["Timestamp"])

# %% [markdown]
# # Inline report

# %%
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>53 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>2491 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>4.1% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>1.0 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>424.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>35 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>17 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><code># MOOCs Finished</code> has 94 / 3.8% missing values <span class="label label-default">Missing</span></l><li><code># MOOCs Started</code> has 52 / 2.1% missing values <span class="label label-default">Missing</span></l><li><code>(Selected answer)</code> has 841 / 33.8% missing values <span class="label label-default">Missing</span></l><li><code>(answered Reasons)</code> has 31 / 1.2% zeros</l><li><code>(selected Aspects)</code> has 405 / 16.3% zeros</l><li><code>(selected Benefits)</code> has 509 / 20.4% zeros</l><li><code>(selected except Not really - Benefits)</code> has 2052 / 82.4% zeros</l><li><code>Aspects: Actively contributing to discussion forums</code> has 1733 / 69.6% zeros</l><li><code>Aspects: Browsing discussion forums</code> has 1149 / 46.1% zeros</l><li><code>Aspects: Connecting with learners outside the course environment</code> has 2109 / 84.7% zeros</l><li><code>Aspects: Connecting with other learners in the course environment</code> has 1537 / 61.7% zeros</l><li><code>Aspects: Taking the course with other people you know (friends, colleagues, etc.)</code> has 2113 / 84.8% zeros</l><li><code>Benefit: Have not taken MOOCs</code> has 2090 / 83.9% zeros</l><li><code>Benefit: Helped me get a new job in a different field</code> has 2385 / 95.7% zeros</l><li><code>Benefit: Helped me get a new job in the same field</code> has 2369 / 95.1% zeros</l><li><code>Benefit: Higher performance evaluation at current job</code> has 2207 / 88.6% zeros</l><li><code>Benefit: Not Really</code> has 1631

# %%
prf = pandas_profiling.ProfileReport(df)

# %%
prf.description_set ['variables']
# Out:
#                                                    count distinct_count  \
# # MOOCs Finished                                    2397              8
# # MOOCs Started                                     2439              8
# (Selected answer)                                   1650              2
# (answered Reasons)                                  2491              6
# (selected Aspects)                                  2491              6
# (selected Benefits)                                 2491              7
# (selected except Not really - Benefits)             2491              5
# Aspects: Actively contributing to discussion fo...  2491              2
# Aspects: Browsing discussion forums                 2491              2
# Aspects: Connecting with learners outside the c...  2491              2
# Aspects: Connecting with other learners in the ...  2491              2
# Aspects: Taking the course with other people yo...  2491              2
# Benefit: Have not taken MOOCs                       2491              2
# Benefit: Helped me get a new job in a different...  2491              2
# Benefit: Helped me get a new job in the same field  2491              2
# Benefit: Higher performance evaluation at curre...  2491              2
# Benefit: Not Really                                 2491              2
# Benefit: Promotion at current organization          2491              2
# Benefit: School credit towards a degree             2491              2
# Decide: Institution/university                      2491              2
# Decide: Instructor                                  2491              2
# Decide: Others recommendations                      2491              2
# Decide: Platform                                    2491              2
# Decide: Ratings                                     2491              2
# Decide: Topic/Subject                               2491              2
# Have you received any tangible benefits from ta...  2296            656
# How familiar are you with MOOCs?                    2468              6
# How important are MOOC certificates to you?         2447             58
# How important is the ability to earn a certific...  2464              6
# How many MOOCs have you  finished?                  2397              8
# How many MOOCs have you started?                    2439              8
# How much do you think employers value MOOC cert...  2372              6
# How willing are you to pay for a certificate fo...  2418              7
# Pay: A multi-course certification that the MOOC...  2090              3
# Pay: The MOOC platform being used                   2090              3
# Pay: The institution/university offering the MOOC   2090              3
# Pay: The instructor/professor                       2090              3
# Pay: The topic/subject                              2090              3
# Reasons: Access to reference materials              2491              2
# Reasons: Learning skills for current career         2491              2
# Reasons: Learning skills for new career             2491              2
# Reasons: Personal interest                          2491              2
# Reasons: School credit                              2491              2
# Timestamp                                           2491           2488
# What is your age range?                             2464             10
# What is your level of formal education?             2452              6
# When did you first start taking MOOCs?              2474              6
# Which are the most important factors in decidin...  2451            177
# Which of the following are important aspects of...  2086             32
# Which of the following are important reasons fo...  2474            167
# Which of the following have a strong impact on ...  2242            338
# Which region of the world are you in?               2441             12
# Why are you interested in taking MOOCs?             1558           1417
#
#                                                    is_unique memorysize  \
# # MOOCs Finished                                       False      20008
# # MOOCs Started                                        False      20008
# (Selected answer)                                      False      20008
# (answered Reasons)                                     False      20008
# (selected Aspects)                                     False      20008
# (selected Benefits)                                    False      20008
# (selected except Not really - Benefits)                False      20008
# Aspects: Actively contributing to discussion fo...     False      20008
# Aspects: Browsing discussion forums                    False      20008
# Aspects: Connecting with learners outside the c...     False      20008
# Aspects: Connecting with other learners in the ...     False      20008
# Aspects: Taking the course with other people yo...     False      20008
# Benefit: Have not taken MOOCs                          False      20008
# Benefit: Helped me get a new job in a different...     False      20008
# Benefit: Helped me get a new job in the same field     False      20008
# Benefit: Higher performance evaluation at curre...     False      20008
# Benefit: Not Really                                    False      20008
# Benefit: Promotion at current organization             False      20008
# Benefit: School credit towards a degree                False      20008
# Decide: Institution/university                         False      20008
# Decide: Instructor                                     False      20008
# Decide: Others recommendations                         False      20008
# Decide: Platform                                       False      20008
# Decide: Ratings                                        False      20008
# Decide: Topic/Subject                                  False      20008
# Have you received any tangible benefits from ta...     False      20008
# How familiar are you with MOOCs?                       False      20008
# How important are MOOC certificates to you?            False      20008
# How important is the ability to earn a certific...     False      20008
# How many MOOCs have you  finished?                     False      20008
# How many MOOCs have you started?                       False      20008
# How much do you think employers value MOOC cert...     False      20008
# How willing are you to pay for a certificate fo...     False      20008
# Pay: A multi-course certification that the MOOC...     False      20008
# Pay: The MOOC platform being used                      False      20008
# Pay: The institution/university offering the MOOC      False      20008
# Pay: The instructor/professor                          False      20008
# Pay: The topic/subject                                 False      20008
# Reasons: Access to reference materials                 False      20008
# Reasons: Learning skills for current career            False      20008
# Reasons: Learning skills for new career                False      20008
# Reasons: Personal interest                             False      20008
# Reasons: School credit                                 False      20008
# Timestamp                                              False      20008
# What is your age range?                                False      20008
# What is your level of formal education?                False      20008
# When did you first start taking MOOCs?                 False      20008
# Which are the most important factors in decidin...     False      20008
# Which of the following are important aspects of...     False      20008
# Which of the following are important reasons fo...     False      20008
# Which of the following have a strong impact on ...     False      20008
# Which region of the world are you in?                  False      20008
# Why are you interested in taking MOOCs?                False      20008
#
#                                                                                  mode  \
# # MOOCs Finished                                                                    0
# # MOOCs Started                                                                     0
# (Selected answer)                                                                 Yes
# (answered Reasons)                                                                  1
# (selected Aspects)                                                                  1
# (selected Benefits)                                                                 1
# (selected except Not really - Benefits)                                             0
# Aspects: Actively contributing to discussion fo...                                  0
# Aspects: Browsing discussion forums                                                 1
# Aspects: Connecting with learners outside the c...                                  0
# Aspects: Connecting with other learners in the ...                                  0
# Aspects: Taking the course with other people yo...                                  0
# Benefit: Have not taken MOOCs                                                       0
# Benefit: Helped me get a new job in a different...                                  0
# Benefit: Helped me get a new job in the same field                                  0
# Benefit: Higher performance evaluation at curre...                                  0
# Benefit: Not Really                                                                 0
# Benefit: Promotion at current organization                                          0
# Benefit: School credit towards a degree                                             0
# Decide: Institution/university                                                      0
# Decide: Instructor                                                                  0
# Decide: Others recommendations                                                      0
# Decide: Platform                                                                    0
# Decide: Ratings                                                                     0
# Decide: Topic/Subject                                                               1
# Have you received any tangible benefits from ta...                         Not really
# How familiar are you with MOOCs?                                                    5
# How important are MOOC certificates to you?              Somewhat/sometimes important
# How important is the ability to earn a certific...                                  5
# How many MOOCs have you  finished?                                               Zero
# How many MOOCs have you started?                    Zero (I have not taken any MOOCs)
# How much do you think employers value MOOC cert...                                  3
# How willing are you to pay for a certificate fo...                                  1
# Pay: A multi-course certification that the MOOC...                                  0
# Pay: The MOOC platform being used                                                   0
# Pay: The institution/university offering the MOOC                                   0
# Pay: The instructor/professor                                                       0
# Pay: The topic/subject                                                              1
# Reasons: Access to reference materials                                              0
# Reasons: Learning skills for current career                                         1
# Reasons: Learning skills for new career                                             0
# Reasons: Personal interest                                                          1
# Reasons: School credit                                                              0
# Timestamp                                                         2017-01-03 02:36:44
# What is your age range?                                               46-55 years old
# What is your level of formal education?                        Graduate school degree
# When did you first start taking MOOCs?                 I have not taken any MOOCs yet
# Which are the most important factors in decidin...               The topic or subject
# Which of the following are important aspects of...         Browsing discussion forums
# Which of the following are important reasons fo...                  Personal interest
# Which of the following have a strong impact on ...                  The topic/subject
# Which region of the world are you in?                                   United States
# Why are you interested in taking MOOCs?                                           yes
#
#                                                    n_infinite n_missing  \
# # MOOCs Finished                                            0        94
# # MOOCs Started                                             0        52
# (Selected answer)                                           0       841
# (answered Reasons)                                          0         0
# (selected Aspects)                                          0         0
# (selected Benefits)                                         0         0
# (selected except Not really - Benefits)                     0         0
# Aspects: Actively contributing to discussion fo...          0         0
# Aspects: Browsing discussion forums                         0         0
# Aspects: Connecting with learners outside the c...          0         0
# Aspects: Connecting with other learners in the ...          0         0
# Aspects: Taking the course with other people yo...          0         0
# Benefit: Have not taken MOOCs                               0         0
# Benefit: Helped me get a new job in a different...          0         0
# Benefit: Helped me get a new job in the same field          0         0
# Benefit: Higher performance evaluation at curre...          0         0
# Benefit: Not Really                                         0         0
# Benefit: Promotion at current organization                  0         0
# Benefit: School credit towards a degree                     0         0
# Decide: Institution/university                              0         0
# Decide: Instructor                                          0         0
# Decide: Others recommendations                              0         0
# Decide: Platform                                            0         0
# Decide: Ratings                                             0         0
# Decide: Topic/Subject                                       0         0
# Have you received any tangible benefits from ta...          0       195
# How familiar are you with MOOCs?                            0        23
# How important are MOOC certificates to you?                 0        44
# How important is the ability to earn a certific...          0        27
# How many MOOCs have you  finished?                          0        94
# How many MOOCs have you started?                            0        52
# How much do you think employers value MOOC cert...          0       119
# How willing are you to pay for a certificate fo...          0        73
# Pay: A multi-course certification that the MOOC...          0       401
# Pay: The MOOC platform being used                           0       401
# Pay: The institution/university offering the MOOC           0       401
# Pay: The instructor/professor                               0       401
# Pay: The topic/subject                                      0       401
# Reasons: Access to reference materials                      0         0
# Reasons: Learning skills for current career                 0         0
# Reasons: Learning skills for new career                     0         0
# Reasons: Personal interest                                  0         0
# Reasons: School credit                                      0         0
# Timestamp                                                   0         0
# What is your age range?                                     0        27
# What is your level of formal education?                     0        39
# When did you first start taking MOOCs?                      0        17
# Which are the most important factors in decidin...          0        40
# Which of the following are important aspects of...          0       405
# Which of the following are important reasons fo...          0        17
# Which of the following have a strong impact on ...          0       249
# Which region of the world are you in?                       0        50
# Why are you interested in taking MOOCs?                     0       933
#
#                                                    p_infinite   p_missing  \
# # MOOCs Finished                                            0   0.0377358
# # MOOCs Started                                             0   0.0208752
# (Selected answer)                                           0    0.337615
# (answered Reasons)                                          0           0
# (selected Aspects)                                          0           0
# (selected Benefits)                                         0           0
# (selected except Not really - Benefits)                     0           0
# Aspects: Actively contributing to discussion fo...          0           0
# Aspects: Browsing discussion forums                         0           0
# Aspects: Connecting with learners outside the c...          0           0
# Aspects: Connecting with other learners in the ...          0           0
# Aspects: Taking the course with other people yo...          0           0
# Benefit: Have not taken MOOCs                               0           0
# Benefit: Helped me get a new job in a different...          0           0
# Benefit: Helped me get a new job in the same field          0           0
# Benefit: Higher performance evaluation at curre...          0           0
# Benefit: Not Really                                         0           0
# Benefit: Promotion at current organization                  0           0
# Benefit: School credit towards a degree                     0           0
# Decide: Institution/university                              0           0
# Decide: Instructor                                          0           0
# Decide: Others recommendations                              0           0
# Decide: Platform                                            0           0
# Decide: Ratings                                             0           0
# Decide: Topic/Subject                                       0           0
# Have you received any tangible benefits from ta...          0   0.0782818
# How familiar are you with MOOCs?                            0  0.00923324
# How important are MOOC certificates to you?                 0   0.0176636
# How important is the ability to earn a certific...          0    0.010839
# How many MOOCs have you  finished?                          0   0.0377358
# How many MOOCs have you started?                            0   0.0208752
# How much do you think employers value MOOC cert...          0    0.047772
# How willing are you to pay for a certificate fo...          0   0.0293055
# Pay: A multi-course certification that the MOOC...          0     0.16098
# Pay: The MOOC platform being used                           0     0.16098
# Pay: The institution/university offering the MOOC           0     0.16098
# Pay: The instructor/professor                               0     0.16098
# Pay: The topic/subject                                      0     0.16098
# Reasons: Access to reference materials                      0           0
# Reasons: Learning skills for current career                 0           0
# Reasons: Learning skills for new career                     0           0
# Reasons: Personal interest                                  0           0
# Reasons: School credit                                      0           0
# Timestamp                                                   0           0
# What is your age range?                                     0    0.010839
# What is your level of formal education?                     0   0.0156564
# When did you first start taking MOOCs?                      0  0.00682457
# Which are the most important factors in decidin...          0   0.0160578
# Which of the following are important aspects of...          0    0.162585
# Which of the following are important reasons fo...          0  0.00682457
# Which of the following have a strong impact on ...          0   0.0999599
# Which region of the world are you in?                       0   0.0200723
# Why are you interested in taking MOOCs?                     0    0.374548
#
#                                                       p_unique    ...      \
# # MOOCs Finished                                    0.00333751    ...
# # MOOCs Started                                     0.00328003    ...
# (Selected answer)                                   0.00121212    ...
# (answered Reasons)                                  0.00240867    ...
# (selected Aspects)                                  0.00240867    ...
# (selected Benefits)                                 0.00281012    ...
# (selected except Not really - Benefits)             0.00200723    ...
# Aspects: Actively contributing to discussion fo...  0.00080289    ...
# Aspects: Browsing discussion forums                 0.00080289    ...
# Aspects: Connecting with learners outside the c...  0.00080289    ...
# Aspects: Connecting with other learners in the ...  0.00080289    ...
# Aspects: Taking the course with other people yo...  0.00080289    ...
# Benefit: Have not taken MOOCs                       0.00080289    ...
# Benefit: Helped me get a new job in a different...  0.00080289    ...
# Benefit: Helped me get a new job in the same field  0.00080289    ...
# Benefit: Higher performance evaluation at curre...  0.00080289    ...
# Benefit: Not Really                                 0.00080289    ...
# Benefit: Promotion at current organization          0.00080289    ...
# Benefit: School credit towards a degree             0.00080289    ...
# Decide: Institution/university                      0.00080289    ...
# Decide: Instructor                                  0.00080289    ...
# Decide: Others recommendations                      0.00080289    ...
# Decide: Platform                                    0.00080289    ...
# Decide: Ratings                                     0.00080289    ...
# Decide: Topic/Subject                               0.00080289    ...
# Have you received any tangible benefits from ta...    0.285714    ...
# How familiar are you with MOOCs?                    0.00243112    ...
# How important are MOOC certificates to you?          0.0237025    ...
# How important is the ability to earn a certific...  0.00243506    ...
# How many MOOCs have you  finished?                  0.00333751    ...
# How many MOOCs have you started?                    0.00328003    ...
# How much do you think employers value MOOC cert...  0.00252951    ...
# How willing are you to pay for a certificate fo...  0.00289495    ...
# Pay: A multi-course certification that the MOOC...  0.00143541    ...
# Pay: The MOOC platform being used                   0.00143541    ...
# Pay: The institution/university offering the MOOC   0.00143541    ...
# Pay: The instructor/professor                       0.00143541    ...
# Pay: The topic/subject                              0.00143541    ...
# Reasons: Access to reference materials              0.00080289    ...
# Reasons: Learning skills for current career         0.00080289    ...
# Reasons: Learning skills for new career             0.00080289    ...
# Reasons: Personal interest                          0.00080289    ...
# Reasons: School credit                              0.00080289    ...
# Timestamp                                             0.998796    ...
# What is your age range?                             0.00405844    ...
# What is your level of formal education?             0.00244698    ...
# When did you first start taking MOOCs?              0.00242522    ...
# Which are the most important factors in decidin...   0.0722154    ...
# Which of the following are important aspects of...   0.0153404    ...
# Which of the following are important reasons fo...    0.067502    ...
# Which of the following have a strong impact on ...    0.150758    ...
# Which region of the world are you in?               0.00491602    ...
# Why are you interested in taking MOOCs?               0.909499    ...
#
#                                                     iqr   kurtosis        mad  \
# # MOOCs Finished                                    NaN        NaN        NaN
# # MOOCs Started                                     NaN        NaN        NaN
# (Selected answer)                                   NaN        NaN        NaN
# (answered Reasons)                                    2  -0.492606   0.924277
# (selected Aspects)                                    1   0.650749   0.953294
# (selected Benefits)                                   0    3.11455   0.588257
# (selected except Not really - Benefits)               0    9.80892   0.386915
# Aspects: Actively contributing to discussion fo...    1   -1.27648   0.423399
# Aspects: Browsing discussion forums                   1    -1.9774   0.496999
# Aspects: Connecting with learners outside the c...    0     1.7079    0.25967
# Aspects: Connecting with other learners in the ...    1   -1.76934   0.472612
# Aspects: Taking the course with other people yo...    0    1.77481   0.257439
# Benefit: Have not taken MOOCs                         0    1.40907    0.27013
# Benefit: Helped me get a new job in a different...    0    18.5841  0.0814848
# Benefit: Helped me get a new job in the same field    0     15.503  0.0931553
# Benefit: Higher performance evaluation at curre...    0    3.91006   0.202024
# Benefit: Not Really                                   1   -1.57696     0.4521
# Benefit: Promotion at current organization            0    29.2145  0.0568934
# Benefit: School credit towards a degree               0      27.44  0.0599115
# Decide: Institution/university                        1   -1.87554   0.484752
# Decide: Instructor                                    0    1.42406   0.269586
# Decide: Others recommendations                        1  -0.700935   0.377496
# Decide: Platform                                      1  -0.946815    0.39583
# Decide: Ratings                                       1   -1.46636   0.441095
# Decide: Topic/Subject                                 0    6.33367   0.162357
# Have you received any tangible benefits from ta...  NaN        NaN        NaN
# How familiar are you with MOOCs?                      3   -1.31262    1.35418
# How important are MOOC certificates to you?         NaN        NaN        NaN
# How important is the ability to earn a certific...    3   -1.22337    1.25825
# How many MOOCs have you  finished?                  NaN        NaN        NaN
# How many MOOCs have you started?                    NaN        NaN        NaN
# How much do you think employers value MOOC cert...    2  -0.558601   0.827004
# How willing are you to pay for a certificate fo...  NaN        NaN        NaN
# Pay: A multi-course certification that the MOOC...    1   -1.17082   0.414155
# Pay: The MOOC platform being used                     0    3.01305   0.222149
# Pay: The institution/university offering the MOOC     1   -1.99158   0.498714
# Pay: The instructor/professor                         0    1.19472   0.278203
# Pay: The topic/subject                                1   -1.95362    0.49405
# Reasons: Access to reference materials                1   -1.03727    0.40303
# Reasons: Learning skills for current career           1   -1.99979   0.499774
# Reasons: Learning skills for new career               1   -1.99552   0.499242
# Reasons: Personal interest                            0  0.0826601   0.328943
# Reasons: School credit                                0    6.69635   0.157722
# Timestamp                                           NaN        NaN        NaN
# What is your age range?                             NaN        NaN        NaN
# What is your level of formal education?             NaN        NaN        NaN
# When did you first start taking MOOCs?              NaN        NaN        NaN
# Which are the most important factors in decidin...  NaN        NaN        NaN
# Which of the following are important aspects of...  NaN        NaN        NaN
# Which of the following are important reasons fo...  NaN        NaN        NaN
# Which of the following have a strong impact on ...  NaN        NaN        NaN
# Which region of the world are you in?               NaN        NaN        NaN
# Why are you interested in taking MOOCs?             NaN        NaN        NaN
#
#                                                          mean n_zeros  \
# # MOOCs Finished                                          NaN     NaN
# # MOOCs Started                                           NaN     NaN
# (Selected answer)                                         NaN     NaN
# (answered Reasons)                                    2.14974      31
# (selected Aspects)                                    1.53111     405
# (selected Benefits)                                   1.11923     509
# (selected except Not really - Benefits)              0.234845    2052
# Aspects: Actively contributing to discussion fo...   0.304295    1733
# Aspects: Browsing discussion forums                  0.538739    1149
# Aspects: Connecting with learners outside the c...   0.153352    2109
# Aspects: Connecting with other learners in the ...   0.382979    1537
# Aspects: Taking the course with other people yo...   0.151746    2113
# Benefit: Have not taken MOOCs                         0.16098    2090
# Benefit: Helped me get a new job in a different...  0.0425532    2385
# Benefit: Helped me get a new job in the same field  0.0489763    2369
# Benefit: Higher performance evaluation at curre...    0.11401    2207
# Benefit: Not Really                                  0.345243    1631
# Benefit: Promotion at current organization          0.0293055    2418
# Benefit: School credit towards a degree             0.0309113    2414
# Decide: Institution/university                       0.412686    1463
# Decide: Instructor                                   0.160578    2091
# Decide: Others recommendations                       0.252509    1862
# Decide: Platform                                     0.271778    1814
# Decide: Ratings                                      0.328382    1673
# Decide: Topic/Subject                                0.910879     222
# Have you received any tangible benefits from ta...        NaN     NaN
# How familiar are you with MOOCs?                      3.34319       0
# How important are MOOC certificates to you?               NaN     NaN
# How important is the ability to earn a certific...     3.2987       0
# How many MOOCs have you  finished?                        NaN     NaN
# How many MOOCs have you started?                          NaN     NaN
# How much do you think employers value MOOC cert...     3.0059       0
# How willing are you to pay for a certificate fo...        NaN     NaN
# Pay: A multi-course certification that the MOOC...   0.292823    1478
# Pay: The MOOC platform being used                    0.127273    1824
# Pay: The institution/university offering the MOOC    0.474641    1098
# Pay: The instructor/professor                        0.166986    1741
# Pay: The topic/subject                               0.554545     931
# Reasons: Access to reference materials               0.279807    1794
# Reasons: Learning skills for current career          0.510638    1219
# Reasons: Learning skills for new career               0.48053    1294
# Reasons: Personal interest                           0.792453     517
# Reasons: School credit                              0.0863107    2276
# Timestamp                                                 NaN     NaN
# What is your age range?                                   NaN     NaN
# What is your level of formal education?                   NaN     NaN
# When did you first start taking MOOCs?                    NaN     NaN
# Which are the most important factors in decidin...        NaN     NaN
# Which of the following are important aspects of...        NaN     NaN
# Which of the following are important reasons fo...        NaN     NaN
# Which of the following have a strong impact on ...        NaN     NaN
# Which region of the world are you in?                     NaN     NaN
# Why are you interested in taking MOOCs?                   NaN     NaN
#
#                                                       p_zeros   skewness  \
# # MOOCs Finished                                          NaN        NaN
# # MOOCs Started                                           NaN        NaN
# (Selected answer)                                         NaN        NaN
# (answered Reasons)                                  0.0124448   0.532546
# (selected Aspects)                                   0.162585   0.934717
# (selected Benefits)                                  0.204336    1.19556
# (selected except Not really - Benefits)              0.823766    2.92184
# Aspects: Actively contributing to discussion fo...   0.695705   0.851201
# Aspects: Browsing discussion forums                  0.461261  -0.155519
# Aspects: Connecting with learners outside the c...   0.846648    1.92524
# Aspects: Connecting with other learners in the ...   0.617021   0.481747
# Aspects: Taking the course with other people yo...   0.848254    1.94252
# Benefit: Have not taken MOOCs                         0.83902    1.84606
# Benefit: Helped me get a new job in a different...   0.957447    4.53533
# Benefit: Helped me get a new job in the same field   0.951024    4.18218
# Benefit: Higher performance evaluation at curre...    0.88599    2.43042
# Benefit: Not Really                                  0.654757   0.651388
# Benefit: Promotion at current organization           0.970695    5.58489
# Benefit: School credit towards a degree              0.969089    5.42383
# Decide: Institution/university                       0.587314   0.354921
# Decide: Instructor                                   0.839422    1.85011
# Decide: Others recommendations                       0.747491    1.14001
# Decide: Platform                                     0.728222    1.02662
# Decide: Ratings                                      0.671618   0.731313
# Decide: Topic/Subject                               0.0891208   -2.88593
# Have you received any tangible benefits from ta...        NaN        NaN
# How familiar are you with MOOCs?                            0  -0.409843
# How important are MOOC certificates to you?               NaN        NaN
# How important is the ability to earn a certific...          0  -0.318113
# How many MOOCs have you  finished?                        NaN        NaN
# How many MOOCs have you started?                          NaN        NaN
# How much do you think employers value MOOC cert...          0  0.0507443
# How willing are you to pay for a certificate fo...        NaN        NaN
# Pay: A multi-course certification that the MOOC...   0.593336   0.911207
# Pay: The MOOC platform being used                    0.732236    2.23834
# Pay: The institution/university offering the MOOC    0.440787   0.101639
# Pay: The instructor/professor                        0.698916    1.78706
# Pay: The topic/subject                               0.373745  -0.219649
# Reasons: Access to reference materials               0.720193   0.981614
# Reasons: Learning skills for current career          0.489362 -0.0425885
# Reasons: Learning skills for new career               0.51947  0.0779865
# Reasons: Personal interest                           0.207547   -1.44312
# Reasons: School credit                               0.913689    2.94805
# Timestamp                                                 NaN        NaN
# What is your age range?                                   NaN        NaN
# What is your level of formal education?                   NaN        NaN
# When did you first start taking MOOCs?                    NaN        NaN
# Which are the most important factors in decidin...        NaN        NaN
# Which of the following are important aspects of...        NaN        NaN
# Which of the following are important reasons fo...        NaN        NaN
# Which of the following have a strong impact on ...        NaN        NaN
# Which region of the world are you in?                     NaN        NaN
# Why are you interested in taking MOOCs?                   NaN        NaN
#
#                                                          std   sum   variance
# # MOOCs Finished                                         NaN   NaN        NaN
# # MOOCs Started                                          NaN   NaN        NaN
# (Selected answer)                                        NaN   NaN        NaN
# (answered Reasons)                                   1.11491  5355    1.24303
# (selected Aspects)                                   1.18056  3814    1.39371
# (selected Benefits)                                 0.855314  2788   0.731562
# (selected except Not really - Benefits)             0.574427   585   0.329966
# Aspects: Actively contributing to discussion fo...  0.460201   758   0.211785
# Aspects: Browsing discussion forums                 0.498597  1342   0.248599
# Aspects: Connecting with learners outside the c...  0.360399   382   0.129887
# Aspects: Connecting with other learners in the ...  0.486211   954   0.236401
# Aspects: Taking the course with other people yo...  0.358847   378   0.128771
# Benefit: Have not taken MOOCs                       0.367586   401   0.135119
# Benefit: Helped me get a new job in a different...  0.201888   106  0.0407588
# Benefit: Helped me get a new job in the same field  0.215862   122  0.0465963
# Benefit: Higher performance evaluation at curre...  0.317888   284   0.101053
# Benefit: Not Really                                 0.475543   860   0.226141
# Benefit: Promotion at current organization          0.168695    73  0.0284581
# Benefit: School credit towards a degree             0.173112    77  0.0299678
# Decide: Institution/university                      0.492416  1028   0.242474
# Decide: Instructor                                  0.367215   400   0.134847
# Decide: Others recommendations                      0.434539   629   0.188824
# Decide: Platform                                    0.444966   677   0.197994
# Decide: Ratings                                     0.469719   818   0.220636
# Decide: Topic/Subject                               0.284975  2269  0.0812109
# Have you received any tangible benefits from ta...       NaN   NaN        NaN
# How familiar are you with MOOCs?                     1.52673  8251    2.33089
# How important are MOOC certificates to you?              NaN   NaN        NaN
# How important is the ability to earn a certific...   1.44631  8128    2.09182
# How many MOOCs have you  finished?                       NaN   NaN        NaN
# How many MOOCs have you started?                         NaN   NaN        NaN
# How much do you think employers value MOOC cert...   1.12446  7130    1.26441
# How willing are you to pay for a certificate fo...       NaN   NaN        NaN
# Pay: A multi-course certification that the MOOC...  0.455167   612   0.207177
# Pay: The MOOC platform being used                   0.333358   266   0.111128
# Pay: The institution/university offering the MOOC   0.499476   992   0.249476
# Pay: The instructor/professor                       0.373052   349   0.139168
# Pay: The topic/subject                              0.497135  1159   0.247143
# Reasons: Access to reference materials              0.448995   697   0.201596
# Reasons: Learning skills for current career         0.499987  1272   0.249987
# Reasons: Learning skills for new career             0.499721  1197   0.249721
# Reasons: Personal interest                          0.405632  1974   0.164537
# Reasons: School credit                              0.280879   215  0.0788928
# Timestamp                                                NaN   NaN        NaN
# What is your age range?                                  NaN   NaN        NaN
# What is your level of formal education?                  NaN   NaN        NaN
# When did you first start taking MOOCs?                   NaN   NaN        NaN
# Which are the most important factors in decidin...       NaN   NaN        NaN
# Which of the following are important aspects of...       NaN   NaN        NaN
# Which of the following are important reasons fo...       NaN   NaN        NaN
# Which of the following have a strong impact on ...       NaN   NaN        NaN
# Which region of the world are you in?                    NaN   NaN        NaN
# Why are you interested in taking MOOCs?                  NaN   NaN        NaN
#
# [53 rows x 34 columns]
